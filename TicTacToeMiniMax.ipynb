# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahalmusabbir/Deep-Learning-Project/blob/main/TicTacToeMiniMax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# Function to print the board
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 5)

# Check for winner
def check_winner(board):
    # Rows, Columns, Diagonals
    for i in range(3):
        if board[i][0] == board[i][1] == board[i][2] and board[i][0] != " ":
            return board[i][0]
        if board[0][i] == board[1][i] == board[2][i] and board[0][i] != " ":
            return board[0][i]
    if board[0][0] == board[1][1] == board[2][2] and board[0][0] != " ":
        return board[0][0]
    if board[0][2] == board[1][1] == board[2][0] and board[0][2] != " ":
        return board[0][2]
    return None

# Check if moves left
def is_moves_left(board):
    for row in board:
        if " " in row:
            return True
    return False

# Minimax with Alpha-Beta pruning
def minimax(board, depth, alpha, beta, is_maximizing, ai_player, human_player):
    winner = check_winner(board)
    if winner == ai_player:
        return 10 - depth
    elif winner == human_player:
        return depth - 10
    elif not is_moves_left(board):
        return 0

    if is_maximizing:
        max_eval = -math.inf
        for i in range(3):
            for j in range(3):
                if board[i][j] == " ":
                    board[i][j] = ai_player
                    eval = minimax(board, depth+1, alpha, beta, False, ai_player, human_player)
                    board[i][j] = " "
                    max_eval = max(max_eval, eval)
                    alpha = max(alpha, eval)
                    if beta <= alpha:
                        break
        return max_eval
    else:
        min_eval = math.inf
        for i in range(3):
            for j in range(3):
                if board[i][j] == " ":
                    board[i][j] = human_player
                    eval = minimax(board, depth+1, alpha, beta, True, ai_player, human_player)
                    board[i][j] = " "
                    min_eval = min(min_eval, eval)
                    beta = min(beta, eval)
                    if beta <= alpha:
                        break
        return min_eval

# Find best move
def find_best_move(board, ai_player, human_player):
    best_val = -math.inf
    best_move = (-1, -1)
    for i in range(3):
        for j in range(3):
            if board[i][j] == " ":
                board[i][j] = ai_player
                move_val = minimax(board, 0, -math.inf, math.inf, False, ai_player, human_player)
                board[i][j] = " "
                if move_val > best_val:
                    best_val = move_val
                    best_move = (i, j)
    return best_move

# %%
def play_human_vs_ai():
    board = [[" " for _ in range(3)] for _ in range(3)]
    human = "X"
    ai = "O"
    turn = "X"

    print("You are X, Computer is O")
    print_board(board)

    while True:
        if turn == human:
            row = int(input("Enter row (0-2): "))
            col = int(input("Enter col (0-2): "))
            if board[row][col] == " ":
                board[row][col] = human
                turn = ai
            else:
                print("Invalid move. Try again.")
        else:
            print("Computer is thinking...")
            move = find_best_move(board, ai, human)
            board[move[0]][move[1]] = ai
            turn = human

        print_board(board)
        winner = check_winner(board)
        if winner:
            print(winner, "wins!")
            break
        if not is_moves_left(board):
            print("It's a draw!")
            break

# Run human vs AI
play_human_vs_ai()
# Out:
# You are X, Computer is O
#   |   |
# -----
#   |   |
# -----
#   |   |
# -----
# Enter row (0-2): 0
# Enter col (0-2): 0
# X |   |
# -----
#   |   |
# -----
#   |   |
# -----
# Computer is thinking...
# X |   |
# -----
#   | O |
# -----
#   |   |
# -----
# Enter row (0-2): 2
# Enter col (0-2): 2
# X |   |
# -----
#   | O |
# -----
#   |   | X
# -----
# Computer is thinking...
# X | O |
# -----
#   | O |
# -----
#   |   | X
# -----
# Enter row (0-2): 0
# Enter col (0-2): 1
# Invalid move. Try again.
# X | O |
# -----
#   | O |
# -----
#   |   | X
# -----
# Enter row (0-2): 0
# Enter col (0-2): 1
# Invalid move. Try again.
# X | O |
# -----
#   | O |
# -----
#   |   | X
# -----
# Enter row (0-2): 2
# Enter col (0-2): 1
# X | O |
# -----
#   | O |
# -----
#   | X | X
# -----
# Computer is thinking...
# X | O |
# -----
#   | O |
# -----
# O | X | X
# -----
# Enter row (0-2): 0
# Enter col (0-2): 2
# X | O | X
# -----
#   | O |
# -----
# O | X | X
# -----
# Computer is thinking...
# ...

# %%
import time

def play_ai_vs_ai():
    board = [[" " for _ in range(3)] for _ in range(3)]
    ai1 = "X"
    ai2 = "O"
    turn = ai1

    print("Computer X vs Computer O")
    print_board(board)

    while True:
        if turn == ai1:
            move = find_best_move(board, ai1, ai2)
            board[move[0]][move[1]] = ai1
            turn = ai2
        else:
            move = find_best_move(board, ai2, ai1)
            board[move[0]][move[1]] = ai2
            turn = ai1

        print_board(board)
        time.sleep(1)  # pause to watch game

        winner = check_winner(board)
        if winner:
            print(winner, "wins!")
            break
        if not is_moves_left(board):
            print("It's a draw!")
            break

# Run AI vs AI
play_ai_vs_ai()
# Out:
# Computer X vs Computer O
#   |   |
# -----
#   |   |
# -----
#   |   |
# -----
# X |   |
# -----
#   |   |
# -----
#   |   |
# -----
# X |   |
# -----
#   | O |
# -----
#   |   |
# -----
# X | X |
# -----
#   | O |
# -----
#   |   |
# -----
# X | X | O
# -----
#   | O |
# -----
#   |   |
# -----
# X | X | O
# -----
#   | O |
# -----
# X |   |
# -----
# X | X | O
# -----
# O | O |
# -----
# X |   |
# -----
# X | X | O
# -----
# O | O | X
# -----
# X |   |
# -----
# X | X | O
# -----
# O | O | X
# -----
# X | O |
# -----
# X | X | O
# -----
# O | O | X
# -----
# X | O | X
# -----
# It's a draw!
